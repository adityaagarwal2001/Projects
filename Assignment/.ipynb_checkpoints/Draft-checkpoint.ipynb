# %%
# Import all required packages

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re
import datetime as dt
import matplotlib.pyplot as plt
import folium 
# %matplotlib inline
from mpl_toolkits.basemap import Basemap
import pandas as pd
import io


sns.set()

# %%
# Read dataset csv file

df = pd.read_csv(r"C:\Users\Adi\Desktop\Assignment\sf_business_dataset.csv", encoding='ANSI')

# Check the basic structure for all features

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216649 entries, 0 to 216648
# Data columns (total 26 columns):
# Location Id                            216649 non-null object
# Business Account Number                216649 non-null int64
# Ownership Name                         216649 non-null object
# DBA Name                               216649 non-null object
# Street Address                         216645 non-null object
# City                                   216380 non-null object
# State                                  215969 non-null object
# Source Zipcode                         216552 non-null float64
# Business Start Date                    216649 non-null object
# Business End Date                      43979 non-null object
# Location Start Date                    216649 non-null object
# Location End Date                      60244 non-null object
# Mail Address                           216647 non-null object
# Mail City                              216597 non-null object
# Mail Zipcode                           216519 non-null object
# Mail State                             216530 non-null object
# NAICS Code                             128933 non-null object
# NAICS Code Description                 126450 non-null object
# Parking Tax                            216649 non-null bool
# Transient Occupancy Tax                216649 non-null bool
# LIC Code                               9891 non-null object
# LIC Code Description                   9891 non-null object
# Supervisor District                    130802 non-null float64
# Neighborhoods - Analysis Boundaries    130797 non-null object
# Business Corridor                      266 non-null object
# Business Location                      175371 non-null object
# dtypes: bool(2), float64(2), int64(1), object(21)
# memory usage: 40.1+ MB

# %% [raw]
# # Assign active business/location flags
#
# df['Active_business'] = np.where(df['Business End Date'].isnull(), 1, 0)
# df['Active_location'] = np.where(df['Location End Date'].isnull(), 1, 0)
#
# print('Business flag:\n', df['Active_business'].value_counts())
# print('Location flag:\n', df['Active_location'].value_counts())
#
# print('Active businesses:\n', df['Business End Date'].isnull().value_counts())
# print('Active locations:\n', df['Location End Date'].isnull().value_counts())

# %% [raw]
# df[(df['Active_business'] == 0) & (df['Active_location'] == 1)]#[['Business End Date', 'Location End Date']]

# %%
# Assign active business/location flags

df['Active_business'] = np.where(df['Business End Date'].isnull(), 1, 0)
df['Active_location'] = np.where(df['Location End Date'].isnull(), 1, 0)

# %%
# Drop rows where Business Location is null

df_location = df.dropna(subset=['Business Location'])

# %% [raw]
# df_location['Business Location'] = df_location['Business Location'].astype(str)
# df_location['City'] = df_location['City'].astype(str)

# %%
# No city value missing
df_location.City.isnull().value_counts()
# Out:
# False    175113
# True        258
# Name: City, dtype: int64

# %%
#df[df['Business Location'].str.contains('(sf|francisco)', regex=True, case=False)]#.City.value_counts()

# %%
df_location['Business Location'].isnull().value_counts()
# Out:
# False    175371
# Name: Business Location, dtype: int64

# %%
# add active business condition

# %%
df_location['lat'] = df_location['Business Location'].str.extract('\(([^()]*)\)', expand=True)\
                                                                    [0].str.split(',', expand=True)[0]

df_location['lon'] = df_location['Business Location'].str.extract('\(([^()]*)\)', expand=True)\
                                                                    [0].str.split(',', expand=True)[1]

df_location.dropna(subset=['lat', 'lon'], inplace=True)

df_location.lon.isnull().value_counts()
# Out:
# C:\Users\Adi\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Adi\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\Adi\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# False    171692
# Name: lon, dtype: int64

# %%
df_location['lat'] = df_location['lat'].apply(pd.to_numeric, errors='coerce')
df_location['lon'] = df_location['lon'].apply(pd.to_numeric, errors='coerce')
# Out:
# C:\Users\Adi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Adi\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_location.rename(columns={'Neighborhoods - Analysis Boundaries': 'Neighborhood'}, inplace=True)
# Out:
# C:\Users\Adi\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
df_location.Neighborhood.isnull().value_counts()
# Out:
# False    115987
# True      55705
# Name: Neighborhood, dtype: int64

# %%
location = df_location[(df_location.Active_business == 1) & (df_location.Active_location == 1)]
location.dropna(subset=['Neighborhood'], inplace=True)
# Out:
# C:\Users\Adi\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
location.Neighborhood.value_counts()
# Out:
# Financial District/South Beach    10392
# Mission                            6268
# Sunset/Parkside                    4435
# South of Market                    4292
# Bayview Hunters Point              3610
# Outer Richmond                     3087
# Marina                             2998
# Chinatown                          2741
# West of Twin Peaks                 2605
# Nob Hill                           2450
# Pacific Heights                    2378
# Castro/Upper Market                2355
# Tenderloin                         2247
# Hayes Valley                       2072
# Inner Richmond                     2010
# Inner Sunset                       1922
# Noe Valley                         1877
# Russian Hill                       1811
# North Beach                        1784
# Potrero Hill                       1759
# Bernal Heights                     1749
# Haight Ashbury                     1634
# Western Addition                   1514
# Excelsior                          1440
# Presidio Heights                   1364
# Lone Mountain/USF                  1098
# Outer Mission                      1074
# Oceanview/Merced/Ingleside         1037
# Mission Bay                         980
# Portola                             662
# Visitacion Valley                   562
# Glen Park                           557
# Lakeshore                           485
# Japantown                           453
# Twin Peaks                          397
# Presidio                            214
# Treasure Island                     200
# Seacliff                            117
# Golden Gate Park                     30
# McLaren Park                         16
# Lincoln Park                         12
# Name: Neighborhood, dtype: int64

# %%
fig, ax = plt.subplots(figsize = (20, 15))
location.Neighborhood.value_counts().plot(kind='barh', ax=ax)

ax.set_xlabel('Total active locations')
ax.set_title('Active businesses/location in SF Neighborhoods')
# Out:
# Text(0.5, 1.0, 'Active businesses/location in SF Neighborhoods')

# %%
fig, ax = plt.subplots(figsize = (15, 15))
location.plot(kind="scatter", x="lon", y="lat", alpha=0.2, ax=ax, marker='.')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [raw]
# SF = [37.7749, -122.4194]
# # Make an empty map
# m = folium.Map(location=SF, zoom_start=12)
#
# # I can add marker one by one on the map
# for i in range(0,len(location)):
#     folium.Marker([location.iloc[i]['lon'], location.iloc[i]['lat']]).add_to(m)
#
# # Save it as html
# m#.save('businesses.html')

# %% [markdown]
# from IPython.display import HTML, display
# m._build_map()
# m, mapHeight = (400,500) # width and height of the displayed iFrame, in pixels
# srcdoc = m.HTML.replace('"', '&quot;')
# embed = HTML('<iframe srcdoc="{}" '
#              'style="width: {}px; height: {}px; display:block; width: 50%; margin: 0 auto; '
#              'border: none"></iframe>'.format(srcdoc, width, height))
# embed

# %%
# read in data to use for plotted points
#buildingdf = pd.read_csv(io.StringIO(u), delimiter=",")
lat = location['lat'].values
lon = location['lon'].values

# determine range to print based on min, max lat and lon of the data
margin = 2 # buffer to add to the range
lat_min = min(lat) - margin
lat_max = max(lat) + margin
lon_min = min(lon) - margin
lon_max = max(lon) + margin

# create map using BASEMAP
m = Basemap(llcrnrlon=lon_min,
            llcrnrlat=lat_min,
            urcrnrlon=lon_max,
            urcrnrlat=lat_max,
            lat_0=(lat_max - lat_min)/2,
            lon_0=(lon_max-lon_min)/2,
            projection='merc',
            resolution = 'h',
            area_thresh=10000.,
            )
m.drawcoastlines()
m.drawcountries()
m.drawstates()
m.drawmapboundary(fill_color='#46bcec')
m.fillcontinents(color = 'white',lake_color='#46bcec')
# convert lat and lon to map projection coordinates
lons, lats = m(lon, lat)
# plot points as red dots
m.scatter(lons, lats, marker = '.', color='r', zorder=5)
plt.show()

# %%
# Remove bad data points

location[location.lat < 35]
# Out:
#            Location Id  Business Account Number  \
# 12171   0190078-01-001                   190078
# 38156   0386934-02-001                   386934
# 133505  1030770-06-151                   355448
# 212118  1030771-06-151                   355448
#
#                        Ownership Name                        DBA Name  \
# 12171   Sanchez-Corea A R & Assocs In  Sanchez A R-Corea & Assocs Inc
# 38156     Stonehouse Ca Olive Oil Llc     Stonehouse Ca Olive Oil Llc
# 133505              Naranjo Fred Jose    Scarborough Insurance Agency
# 212118              Naranjo Fred Jose                             Sia
#
#                    Street Address           City State  Source Zipcode  \
# 12171   301 Junipero Serra Bl 270  San Francisco    CA         94127.0
# 38156           1 The Embarcadero  San Francisco    CA         94111.0
# 133505         99 The Embarcadero  San Francisco    CA         94105.0
# 212118         99 The Embarcadero  San Francisco    CA         94105.0
#
#        Business Start Date Business End Date     ...     LIC Code  \
# 12171             7/1/1989               NaN     ...          NaN
# 38156            10/1/2003               NaN     ...          H07
# 133505            5/2/2002               NaN     ...          NaN
# 212118            5/2/2002               NaN     ...          NaN
#
#                                 LIC Code Description Supervisor District  \
# 12171                                            NaN                 7.0
# 38156   Retail Food Market W/food Prep. Lt 5001 Sqft                 6.0
# 133505                                           NaN                 3.0
# 212118                                           NaN                 3.0
#
#                           Neighborhood Business Corridor  \
# 12171               West of Twin Peaks               NaN
# 38156   Financial District/South Beach               NaN
# 133505  Financial District/South Beach               NaN
# 212118  Financial District/South Beach               NaN
#
#                                         Business Location Active_business  \
# 12171   301 JUNIPERO\rSan Francisco, CA 94127\r(34.098...               1
# 38156   1 THE\rEMBARCADERO San Francisco, CA 94111\r(3...               1
# 133505  99 THE\rEMBARCADERO SAN FRANCISCO, CA 94105\r(...               1
# 212118  99 THE\rEMBARCADERO SAN FRANCISCO, CA 94105\r(...               1
#
#        Active_location        lat         lon
# 12171                1  34.098835 -118.105624
# 38156                1  32.625700 -117.136796
# 133505               1  32.625751 -117.136767
# 212118               1  32.625751 -117.136767
#
# [4 rows x 30 columns]

# %%
location.lat.sort_values(ascending=True)
# Out:
# 38156     32.625700
# 133505    32.625751
# 212118    32.625751
# 12171     34.098835
# 59022     37.639680
# 35691     37.639680
# 124163    37.644538
# 97847     37.645520
# 211430    37.649080
# 206727    37.649799
# 150256    37.650364
# 133860    37.653460
# 147232    37.656684
# 12585     37.656826
# 134769    37.657929
# 69245     37.658209
# 155851    37.659985
# 135783    37.664050
# 45299     37.668434
# 142957    37.669164
# 62856     37.669186
# 153481    37.672672
# 130222    37.708130
# 34083     37.708214
# 32725     37.708214
# 108236    37.708222
# 88130     37.708255
# 113749    37.708260
# 72578     37.708270
# 72577     37.708270
#             ...
# 154841    37.829613
# 102306    37.830055
# 102299    37.830055
# 35077     37.830277
# 151450    37.830277
# 61353     37.830636
# 20942     37.830681
# 197107    37.830681
# 20943     37.830681
# 131923    37.831030
# 144016    37.831030
# 155448    37.831126
# 134961    37.831317
# 59519     37.960629
# 18823     37.960629
# 29068     37.960629
# 57657     37.960629
# 68587     37.960629
# 12976     37.960629
# 57656     37.960629
# 43647     37.960629
# 70741     37.960629
# 1696      37.960629
# 12977     37.960629
# 33752     37.960629
# 86025     38.105022
# 23776     38.105022
# 648       38.106234
# 208379    38.107394
# 18153     38.108154
# Name: lat, Length: 78688, dtype: float64

# %%
location.drop(location[(location.lat < 37) | (location.lat > 37.9)].index, inplace=True)
# Out:
# C:\Users\Adi\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
location = df['Business Location'].str.split('(', expand=True)[1].str.split(')', expand=True)[0].str.split(',', expand=True)

# %%
df['lat'] = location[0]
df['lon'] = location[1]

# %%
df_active_business['lat'] = pd.to_numeric(df_active_business['lat'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-c5fe7f491636> in <module>
# ----> 1 df_active_business['lat'] = pd.to_numeric(df_active_business['lat'])
#
# NameError: name 'df_active_business' is not defined

# %%
df_active_business.lat.isnull().value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-d9cb976c5639> in <module>
# ----> 1 df_active_business.lat.isnull().value_counts()
#
# NameError: name 'df_active_business' is not defined

# %%
df_active_business.lon.isnull().value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-4660c7409969> in <module>
# ----> 1 df_active_business.lon.isnull().value_counts()
#
# NameError: name 'df_active_business' is not defined

# %%
df_active_business = df[(df['Active_business'] == 1) & (df['Active_location'] == 1)]

# %%
df_active_business = df_active_business.dropna(subset=['lat', 'lon'])

# %%
active_neighborhoods = df_active_business.groupby(['Neighborhoods - Analysis Boundaries'])\
                                                    ['Active_business'].count().sort_values(ascending=False)

# %%
print("Active businesses:", active_neighborhoods)
# Out:
# Active businesses: Neighborhoods - Analysis Boundaries
# Financial District/South Beach    10392
# Mission                            6268
# Sunset/Parkside                    4435
# South of Market                    4292
# Bayview Hunters Point              3610
# Outer Richmond                     3087
# Marina                             2998
# Chinatown                          2741
# West of Twin Peaks                 2605
# Nob Hill                           2450
# Pacific Heights                    2378
# Castro/Upper Market                2356
# Tenderloin                         2247
# Hayes Valley                       2072
# Inner Richmond                     2010
# Inner Sunset                       1922
# Noe Valley                         1877
# Russian Hill                       1811
# North Beach                        1785
# Potrero Hill                       1759
# Bernal Heights                     1749
# Haight Ashbury                     1634
# Western Addition                   1514
# Excelsior                          1440
# Presidio Heights                   1365
# Lone Mountain/USF                  1098
# Outer Mission                      1074
# Oceanview/Merced/Ingleside         1037
# Mission Bay                         980
# Portola                             662
# Visitacion Valley                   562
# Glen Park                           557
# Lakeshore                           485
# Japantown                           453
# Twin Peaks                          397
# Presidio                            214
# Treasure Island                     200
# Seacliff                            117
# Golden Gate Park                     30
# McLaren Park                         16
# Lincoln Park                         12
# Name: Active_business, dtype: int64

# %%
import folium
from IPython.display import HTML

# %%
def display(m, height=300):
    """Takes a folium instance and embed HTML."""
    m._build_map()
    srcdoc = m.HTML.replace('"', '&quot;')
    embed = HTML('<iframe srcdoc="{0}" '
                 'style="width: 100%; height: {1}px; '
                 'border: none"></iframe>'.format(srcdoc, height))
    return embed

# %%
map = folium.Map(location=[37.76, -122.45])
map.simple_marker([37.76, -122.45])
display(map)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-6522b860701c> in <module>()
#       1 map = folium.Map(location=[37.76, -122.45])
# ----> 2 map.simple_marker([37.76, -122.45])
#       3 display(map)
#
# AttributeError: 'Map' object has no attribute 'simple_marker'

# %%
SF_COORDINATES = (37.7749, -122.4194)
#crimedata = pd.read_csv('SFPD_Incidents_-_Current_Year__2015_.csv')
 
# for speed purposes
#MAX_RECORDS = 1000
  
# create empty map zoomed in on San Francisco
map = folium.Map(location=SF_COORDINATES, zoom_start=12)
 
# add a marker for every record in the filtered data, use a clustered view
for each in df_active_business.iterrows():
    folium.Marker(location = [each['lat'],each['lon']], clustered_marker = True)
  
display(map)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-abd99ad2035b> in <module>()
#      10 # add a marker for every record in the filtered data, use a clustered view
#      11 for each in df_active_business.iterrows():
# ---> 12     folium.Marker(location = [each['lat'],each['lon']], clustered_marker = True)
#      13
#      14 display(map)
#
# TypeError: tuple indices must be integers or slices, not str

# %%
NAICS = pd.read_excel(r"C:\Users\Adi\Desktop\Assignment\data_dictionary.xlsx", sheet_name='NAICS Codes')
NAICS
# Out:
#    NAICS Code                                       Description
# 0   7210-7219                                   Accommodations
# 1         NaN                                               NaN
# 2   5600-5699               Administrative and Support Services
# 3   7100-7199               Arts, Entertainment, and Recreation
# 4   8110-8139                                  Certain Services
# 5   2300-2399                                      Construction
# 6   5210-5239                                Financial Services
# 7   7220-7229                                     Food Services
# 8   5100-5199                                       Information
# 9   5240-5249                                         Insurance
# 10  3100-3399                                     Manufacturing
# 11  6100-6299             Private Education and Health Services
# 12  5400-5499  Professional, Scientific, and Technical Services
# 13  5300-5399       Real Estate and Rental and Leasing Services
# 14  4400-4599                                      Retail Trade
# 15  4800-4999                    Transportation and Warehousing
# 16  2200-2299                                         Utilities
# 17  4200-4299                                   Wholesale Trade
# 18  8100-8399                                  Certain Services

# %%
df_NAICS = df.dropna(subset=['NAICS Code'])

# %%
# Check if NAICS description is null for any rows

df_NAICS[df_NAICS['NAICS Code Description'].isnull()]['NAICS Code'].value_counts()
# Out:
# 8100-8139    2483
# Name: NAICS Code, dtype: int64

# %%
# Correcting NAICS code. Assumption - value should be 8110-8139

df_NAICS.loc[df_NAICS['NAICS Code Description'].isnull(), ['NAICS Code']] = '8110-8139'

# %%
df_NAICS = df_NAICS.merge(NAICS, on='NAICS Code')

# %%
df_NAICS['Description'].isnull().value_counts()
# Out:
# False    128933
# Name: Description, dtype: int64

# %%
df_NAICS.drop(df_NAICS[df_NAICS.Active_business == 0].index, inplace=True)
df_NAICS.drop(df_NAICS[df_NAICS.Active_location == 0].index, inplace=True)
df_NAICS.dropna(subset=['Neighborhoods - Analysis Boundaries'], inplace=True)

# %%
less_popular = df_NAICS['Description'].value_counts(ascending=True)[:5].index

# %%
NAICS[NAICS.Description.isin(less_popular)].reset_index(drop=True)
# Out:
#   NAICS Code                          Description
# 0  5600-5699  Administrative and Support Services
# 1  5100-5199                          Information
# 2  5240-5249                            Insurance
# 3  3100-3399                        Manufacturing
# 4  2200-2299                            Utilities

# %%
df_NAICS.head()
# Out:
#        Location Id  Business Account Number               Ownership Name  \
# 2   0027660-01-001                    27660             Sunset Glass Inc
# 8   0037683-02-001                    37683  Sand Joseph C Jr & Robert F
# 9   0037683-03-001                    37683  Sand Joseph C Jr & Robert F
# 10  0037683-04-001                    37683  Sand Joseph C Jr & Robert F
# 11  0037683-05-001                    37683  Sand Joseph C Jr & Robert F
#
#                 DBA Name  Street Address           City State  Source Zipcode  \
# 2       Sunset Glass Inc  4301 Irving St  San Francisco    CA         94122.0
# 8   149-151 Dolores Apts  149 Dolores St  San Francisco    CA         94103.0
# 9    262-298 Church Apts   262 Church St  San Francisco    CA         94114.0
# 10  Sand Joseph C Co Inc   262 Church St  San Francisco    CA         94114.0
# 11  2043-45 15th St Apts    2043 15th St  San Francisco    CA         94114.0
#
#    Business Start Date Business End Date      ...      LIC Code Description  \
# 2            10/1/1968               NaN      ...                       NaN
# 8            10/1/1968               NaN      ...                       NaN
# 9            10/1/1968               NaN      ...                       NaN
# 10           10/1/1968               NaN      ...                       NaN
# 11           10/1/1968               NaN      ...                       NaN
#
#    Supervisor District Neighborhoods - Analysis Boundaries Business Corridor  \
# 2                  4.0                     Sunset/Parkside               NaN
# 8                  8.0                             Mission               NaN
# 9                  8.0                 Castro/Upper Market               NaN
# 10                 8.0                 Castro/Upper Market               NaN
# 11                 8.0                 Castro/Upper Market               NaN
#
#                                     Business Location Active_business  \
# 2   4301 IRVING ST\rSan Francisco, CA 94122\r(37.7...               1
# 8   149 DOLORES ST\rSan Francisco, CA 94103\r(37.7...               1
# 9   262 CHURCH ST\rSan Francisco, CA 94114\r(37.76...               1
# 10  262 CHURCH ST\rSan Francisco, CA 94114\r(37.76...               1
# 11  2043 15TH ST\rSan Francisco, CA 94114\r(37.766...               1
#
#    Active_location        lat           lon   Description
# 2                1  37.762385   -122.504083  Construction
# 8                1  37.767197   -122.426579  Construction
# 9                1   37.76636   -122.428841  Construction
# 10               1   37.76636   -122.428841  Construction
# 11               1  37.766098   -122.429681  Construction
#
# [5 rows x 31 columns]

# %%
df_industry = df.dropna(subset=['NAICS Code'])
df_industry[df_industry['NAICS Code Description'].isnull()]['NAICS Code'].value_counts()
df_industry.loc[df_industry['NAICS Code Description'].isnull(), ['NAICS Code']] = '8110-8139'
df_industry = df_industry.merge(NAICS, on='NAICS Code')

# %%
df_industry.dropna(subset=['Neighborhoods - Analysis Boundaries'], inplace=True)

# %%
df_industry['Location Start Date'] = pd.to_datetime(df_industry['Location Start Date'])
df_industry['year'] = df_industry['Location Start Date'].dt.year

# %%
df_industry.drop(df_industry[(df_industry['year'] < 1965)].index, inplace=True)

# %%
df_industry.groupby(['year', 'Description']).size().unstack('Description')
# Out:
# Description  Accommodations   Administrative and Support Services  \
# year
# 1965                     NaN                                  NaN
# 1966                     NaN                                  NaN
# 1967                     NaN                                  NaN
# 1968                    68.0                                 17.0
# 1969                     4.0                                  2.0
# 1970                     3.0                                 10.0
# 1971                     9.0                                  4.0
# 1972                    10.0                                  2.0
# 1973                    13.0                                  2.0
# 1974                    11.0                                  NaN
# 1975                    16.0                                  2.0
# 1976                    10.0                                  2.0
# 1977                    11.0                                  NaN
# 1978                     8.0                                  NaN
# 1979                    10.0                                  NaN
# 1980                     3.0                                  2.0
# 1981                     9.0                                  1.0
# 1982                     3.0                                  1.0
# 1983                     4.0                                  NaN
# 1984                     6.0                                  1.0
# 1985                     5.0                                  4.0
# 1986                    10.0                                  5.0
# 1987                    14.0                                  5.0
# 1988                    15.0                                  3.0
# 1989                    18.0                                  5.0
# 1990                     5.0                                  2.0
# 1991                     7.0                                  2.0
# 1992                     4.0                                  5.0
# 1993                     7.0                                  6.0
# 1994                     9.0                                  9.0
# 1995                    10.0                                 10.0
# 1996                    10.0                                 10.0
# 1997                     8.0                                 16.0
# 1998                    17.0                                 12.0
# 1999                    18.0                                 22.0
# 2000                    11.0                                 25.0
# 2001                    17.0                                 23.0
# 2002                    23.0                                 16.0
# 2003                    23.0                                 34.0
# 2004                    18.0                                 32.0
# 2005                    25.0                                 39.0
# 2006                    41.0                                 65.0
# 2007                   115.0                                 39.0
# 2008                    25.0                                 61.0
# 2009                    40.0                                 84.0
# 2010                    29.0                                 85.0
# 2011                    45.0                                103.0
# 2012                    81.0                                 96.0
# 2013                    91.0                                123.0
# 2014                   148.0                                219.0
# 2015                   827.0                                112.0
# 2016                   812.0                                243.0
# 2017                   388.0                                186.0
# 2020                     NaN                                  NaN
# 2021                     2.0                                  NaN
# 2024                     NaN                                  NaN
#
# Description  Arts, Entertainment, and Recreation  Certain Services  \
# year
# 1965                                         3.0               NaN
# 1966                                         2.0               NaN
# 1967                                         1.0               NaN
# 1968                                         5.0               9.0
# 1969                                         2.0               1.0
# 1970                                         3.0               2.0
# 1971                                         2.0               NaN
# 1972                                         4.0               2.0
# 1973                                         2.0               NaN
# 1974                                         6.0               NaN
# 1975                                         1.0               7.0
# 1976                                         4.0               1.0
# 1977                                         9.0               1.0
# 1978                                         1.0               4.0
# 1979                                         5.0               3.0
# 1980                                         6.0               9.0
# 1981                                         5.0               2.0
# 1982                                         2.0               NaN
# 1983                                         6.0               5.0
# 1984                                         4.0               2.0
# 1985                                         6.0               5.0
# 1986                                        12.0               6.0
# 1987                                         9.0               4.0
# 1988                                        11.0              10.0
# 1989                                        15.0              12.0
# 1990                                        12.0               9.0
# 1991                                         7.0              11.0
# 1992                                        15.0              13.0
# 1993                                        18.0              12.0
# 1994                                        24.0              18.0
# 1995                                        30.0              19.0
# 1996                                        45.0              18.0
# 1997                                        36.0              28.0
# 1998                                        46.0              26.0
# 1999                                        78.0              41.0
# 2000                                        63.0              36.0
# 2001                                        78.0              28.0
# 2002                                        80.0              40.0
# 2003                                        82.0              55.0
# 2004                                       119.0              68.0
# 2005                                       115.0              62.0
# 2006                                       118.0              65.0
# 2007                                       150.0              96.0
# 2008                                       177.0              91.0
# 2009                                       174.0             109.0
# 2010                                       195.0             122.0
# 2011                                       240.0             147.0
# 2012                                       285.0             162.0
# 2013                                       345.0             202.0
# 2014                                       351.0             152.0
# 2015                                       294.0             115.0
# 2016                                       487.0             189.0
# 2017                                       230.0              98.0
# 2020                                         NaN               1.0
# 2021                                         NaN               NaN
# 2024                                         NaN               NaN
#
# Description  Construction  Financial Services  Food Services  Information  \
# year
# 1965                  NaN                 NaN            NaN          NaN
# 1966                  NaN                 NaN            NaN          NaN
# 1967                  NaN                 NaN            NaN          NaN
# 1968                 20.0                 7.0           31.0          7.0
# 1969                  3.0                 NaN            5.0          NaN
# 1970                  5.0                 2.0            4.0          1.0
# 1971                  3.0                 2.0            3.0          1.0
# 1972                  3.0                 2.0            3.0          NaN
# 1973                  NaN                 NaN            8.0          NaN
# 1974                  1.0                 NaN            7.0          NaN
# 1975                  6.0                 NaN            3.0          1.0
# 1976                  2.0                 NaN            5.0          2.0
# 1977                  2.0                 4.0            5.0          1.0
# 1978                  5.0                 1.0            6.0          1.0
# 1979                  6.0                 2.0            6.0          2.0
# 1980                  5.0                 1.0            6.0          1.0
# 1981                  5.0                 1.0           12.0          NaN
# 1982                  7.0                 4.0           10.0          2.0
# 1983                  9.0                10.0            4.0          1.0
# 1984                  4.0                 NaN           10.0          1.0
# 1985                 13.0                 5.0           12.0          1.0
# 1986                  9.0                 2.0           13.0          NaN
# 1987                 12.0                 3.0           20.0          3.0
# 1988                 46.0                 5.0           17.0          1.0
# 1989                 27.0                 5.0           27.0          2.0
# 1990                 20.0                 5.0           12.0          2.0
# 1991                 18.0                 2.0           16.0          2.0
# 1992                 25.0                 4.0           32.0          3.0
# 1993                 24.0                 5.0           24.0          2.0
# 1994                 30.0                11.0           41.0          2.0
# 1995                 40.0                 8.0           58.0         16.0
# 1996                 56.0                10.0           55.0         12.0
# 1997                 46.0                12.0           63.0         12.0
# 1998                 51.0                25.0           76.0          5.0
# 1999                 80.0                42.0           70.0         10.0
# 2000                 86.0                37.0           74.0         41.0
# 2001                 98.0                29.0           80.0         18.0
# 2002                 97.0                42.0           88.0         22.0
# 2003                107.0                48.0          110.0         21.0
# 2004                151.0                58.0          122.0         31.0
# 2005                161.0                73.0          127.0         40.0
# 2006                141.0                83.0          184.0         50.0
# 2007                166.0                95.0          145.0         56.0
# 2008                203.0                74.0          179.0         57.0
# 2009                194.0                99.0          200.0         70.0
# 2010                256.0               149.0          254.0         89.0
# 2011                331.0               152.0          385.0        126.0
# 2012                280.0               226.0          420.0        230.0
# 2013                316.0               212.0          523.0        240.0
# 2014                293.0               217.0          388.0        176.0
# 2015                228.0               165.0          286.0        207.0
# 2016                383.0               215.0          382.0        307.0
# 2017                172.0                89.0          259.0        107.0
# 2020                  NaN                 NaN            NaN          NaN
# 2021                  NaN                 NaN            NaN          NaN
# 2024                  NaN                 NaN            NaN          NaN
#
# Description  Insurance  Manufacturing  Private Education and Health Services  \
# year
# 1965               1.0            NaN                                    4.0
# 1966               NaN            NaN                                    1.0
# 1967               NaN            NaN                                    1.0
# 1968               4.0           30.0                                   21.0
# 1969               1.0            6.0                                    5.0
# 1970               NaN            NaN                                    4.0
# 1971               1.0            2.0                                    9.0
# 1972               3.0            NaN                                    6.0
# 1973               2.0            NaN                                    8.0
# 1974               1.0            NaN                                    5.0
# 1975               NaN            2.0                                    4.0
# 1976               1.0            1.0                                   15.0
# 1977               NaN            3.0                                    7.0
# 1978               NaN            2.0                                    8.0
# 1979               1.0            NaN                                   11.0
# 1980               NaN            NaN                                   10.0
# 1981               NaN            2.0                                    7.0
# 1982               NaN            2.0                                   16.0
# 1983               NaN            NaN                                   10.0
# 1984               6.0            2.0                                   18.0
# 1985               2.0            5.0                                    8.0
# 1986               NaN            5.0                                   11.0
# 1987               2.0            1.0                                   15.0
# 1988               NaN            4.0                                   19.0
# 1989               5.0            9.0                                   35.0
# 1990               3.0            3.0                                   19.0
# 1991               1.0            5.0                                   36.0
# 1992               3.0            4.0                                   24.0
# 1993               NaN            6.0                                   25.0
# 1994               3.0            8.0                                   25.0
# 1995               1.0            9.0                                   69.0
# 1996               5.0           13.0                                   38.0
# 1997               2.0           10.0                                   47.0
# 1998               4.0           10.0                                   62.0
# 1999               3.0           14.0                                   81.0
# 2000               6.0           26.0                                   78.0
# 2001               7.0           10.0                                   69.0
# 2002               8.0           19.0                                   77.0
# 2003              10.0           20.0                                   98.0
# 2004               7.0           24.0                                  138.0
# 2005               8.0           21.0                                  129.0
# 2006              14.0           32.0                                  113.0
# 2007              18.0           40.0                                  157.0
# 2008              19.0           44.0                                  184.0
# 2009              23.0           37.0                                  198.0
# 2010              25.0           54.0                                  247.0
# 2011              32.0           60.0                                  325.0
# 2012              28.0           70.0                                  333.0
# 2013              40.0           97.0                                  329.0
# 2014              34.0           80.0                                  272.0
# 2015              21.0           90.0                                  252.0
# 2016              37.0          110.0                                  376.0
# 2017              10.0           45.0                                  192.0
# 2020               NaN            NaN                                    NaN
# 2021               NaN            NaN                                    NaN
# 2024               NaN            NaN                                    1.0
#
# Description  Professional, Scientific, and Technical Services  \
# year
# 1965                                                      NaN
# 1966                                                      NaN
# 1967                                                      NaN
# 1968                                                     47.0
# 1969                                                      8.0
# 1970                                                      6.0
# 1971                                                     13.0
# 1972                                                     10.0
# 1973                                                      8.0
# 1974                                                     13.0
# 1975                                                     17.0
# 1976                                                     18.0
# 1977                                                     17.0
# 1978                                                      8.0
# 1979                                                     14.0
# 1980                                                     17.0
# 1981                                                     16.0
# 1982                                                     14.0
# 1983                                                     13.0
# 1984                                                     18.0
# 1985                                                     20.0
# 1986                                                     18.0
# 1987                                                     28.0
# 1988                                                     32.0
# 1989                                                     56.0
# 1990                                                     30.0
# 1991                                                     38.0
# 1992                                                     49.0
# 1993                                                     41.0
# 1994                                                     70.0
# 1995                                                    101.0
# 1996                                                    118.0
# 1997                                                    141.0
# 1998                                                    139.0
# 1999                                                    194.0
# 2000                                                    213.0
# 2001                                                    184.0
# 2002                                                    289.0
# 2003                                                    271.0
# 2004                                                    368.0
# 2005                                                    387.0
# 2006                                                    401.0
# 2007                                                    440.0
# 2008                                                    505.0
# 2009                                                    642.0
# 2010                                                    786.0
# 2011                                                    906.0
# 2012                                                   1008.0
# 2013                                                   1135.0
# 2014                                                    998.0
# 2015                                                    916.0
# 2016                                                   1372.0
# 2017                                                    592.0
# 2020                                                      NaN
# 2021                                                      NaN
# 2024                                                      NaN
#
# Description  Real Estate and Rental and Leasing Services  Retail Trade  \
# year
# 1965                                                 NaN           NaN
# 1966                                                 1.0           NaN
# 1967                                                 1.0           NaN
# 1968                                              1100.0          77.0
# 1969                                               122.0           5.0
# 1970                                                93.0           9.0
# 1971                                               122.0           9.0
# 1972                                               127.0           9.0
# 1973                                               129.0           8.0
# 1974                                               132.0          12.0
# 1975                                               132.0          12.0
# 1976                                               196.0          16.0
# 1977                                               139.0          16.0
# 1978                                               143.0          17.0
# 1979                                                94.0          14.0
# 1980                                                74.0          19.0
# 1981                                                70.0          16.0
# 1982                                                56.0          16.0
# 1983                                                63.0          16.0
# 1984                                               120.0          26.0
# 1985                                                70.0          21.0
# 1986                                               161.0          22.0
# 1987                                               269.0          31.0
# 1988                                               277.0          33.0
# 1989                                               385.0          38.0
# 1990                                               118.0          26.0
# 1991                                               103.0          29.0
# 1992                                               104.0          41.0
# 1993                                               142.0          44.0
# 1994                                               136.0          57.0
# 1995                                               141.0          66.0
# 1996                                               200.0          72.0
# 1997                                               187.0         117.0
# 1998                                               246.0         126.0
# 1999                                               266.0         108.0
# 2000                                               297.0         131.0
# 2001                                               201.0         125.0
# 2002                                               272.0         175.0
# 2003                                               227.0         184.0
# 2004                                               224.0         237.0
# 2005                                               327.0         186.0
# 2006                                               268.0         234.0
# 2007                                              1459.0         263.0
# 2008                                               310.0         266.0
# 2009                                               346.0         334.0
# 2010                                               380.0         363.0
# 2011                                               561.0         471.0
# 2012                                               637.0         555.0
# 2013                                               663.0         602.0
# 2014                                              1241.0         441.0
# 2015                                               777.0         387.0
# 2016                                               726.0         638.0
# 2017                                               299.0         296.0
# 2020                                                 NaN           NaN
# 2021                                                 NaN           NaN
# 2024                                                 NaN           NaN
#
# Description  Transportation and Warehousing  Utilities  Wholesale Trade
# year
# 1965                                    NaN        1.0              NaN
# 1966                                    NaN        NaN              NaN
# 1967                                    NaN        NaN              NaN
# 1968                                    5.0        NaN             34.0
# 1969                                    NaN        NaN              NaN
# 1970                                    3.0        NaN              NaN
# 1971                                    1.0        NaN              2.0
# 1972                                    1.0        NaN              2.0
# 1973                                    NaN        NaN              2.0
# 1974                                    NaN        NaN              3.0
# 1975                                    1.0        NaN              2.0
# 1976                                    NaN        NaN              6.0
# 1977                                    NaN        NaN              6.0
# 1978                                    4.0        NaN              6.0
# 1979                                    NaN        NaN              8.0
# 1980                                    1.0        NaN              3.0
# 1981                                    NaN        NaN              8.0
# 1982                                    NaN        NaN              4.0
# 1983                                    NaN        NaN              3.0
# 1984                                    NaN        2.0              7.0
# 1985                                    NaN        NaN              6.0
# 1986                                    1.0        NaN              8.0
# 1987                                    4.0        1.0              7.0
# 1988                                    NaN        1.0              9.0
# 1989                                    3.0        NaN              8.0
# 1990                                    NaN        NaN             13.0
# 1991                                    NaN        NaN             13.0
# 1992                                    1.0        NaN             12.0
# 1993                                    2.0        NaN             12.0
# 1994                                    3.0        1.0             20.0
# 1995                                    3.0        NaN             17.0
# 1996                                    7.0        2.0             30.0
# 1997                                    5.0        1.0             32.0
# 1998                                    9.0        2.0             34.0
# 1999                                   10.0        2.0             57.0
# 2000                                    9.0        1.0             35.0
# 2001                                   13.0        5.0             47.0
# 2002                                   26.0        NaN             62.0
# 2003                                   19.0        1.0             55.0
# 2004                                   21.0        3.0             46.0
# 2005                                   21.0        NaN             73.0
# 2006                                   29.0        NaN             79.0
# 2007                                  476.0        2.0             63.0
# 2008                                   46.0        3.0            108.0
# 2009                                   67.0        4.0            108.0
# 2010                                   72.0        7.0            112.0
# 2011                                   75.0        2.0            152.0
# 2012                                  126.0        8.0            174.0
# 2013                                  208.0        7.0            143.0
# 2014                                  423.0        5.0            143.0
# 2015                                  991.0        4.0            116.0
# 2016                                 3306.0       13.0            164.0
# 2017                                  194.0        1.0             79.0
# 2020                                    NaN        NaN              NaN
# 2021                                    NaN        NaN              NaN
# 2024                                    NaN        NaN              NaN

# %%
data = df_industry.groupby(['year', 'Description']).size().unstack('Description')

# %%
columns = data.columns

# %%
# Plot monthly s_ratio for all years 
fig, ax = plt.subplots(figsize=(20,20))
df_industry.groupby(['year', 'Description']).size().unstack('Description').plot(ax=ax)

# %%
df_industry.year
# Out:
# 0         1968
# 1         1995
# 2         1968
# 8         1970
# 9         1970
# 10        1968
# 11        1990
# 14        2009
# 15        2010
# 16        1968
# 19        1988
# 20        2001
# 21        2001
# 22        2000
# 24        2000
# 25        1999
# 30        2001
# 34        2012
# 42        1969
# 45        1969
# 48        2005
# 49        1970
# 50        2014
# 52        1969
# 54        1970
# 56        2011
# 69        1968
# 72        2004
# 73        2004
# 74        1972
#           ...
# 128785    1996
# 128792    2010
# 128799    2014
# 128801    2007
# 128803    2014
# 128809    2015
# 128813    2015
# 128820    2015
# 128826    2015
# 128830    2016
# 128834    2016
# 128836    2016
# 128840    2016
# 128842    2016
# 128856    2010
# 128864    2016
# 128865    2016
# 128866    2016
# 128874    2016
# 128883    2016
# 128885    2016
# 128886    2016
# 128903    2017
# 128917    1998
# 128921    1997
# 128922    2003
# 128925    2000
# 128926    2012
# 128929    2014
# 128930    2016
# Name: year, Length: 73170, dtype: int64
